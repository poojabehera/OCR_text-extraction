# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df= pd.read_csv("C:/Users/LZ575NE/OneDrive - EY/Desktop/Consumer_Complaints.csv")

# %%
df.shape
# Out:
# (1025010, 19)

# %%
df.head(3)
# Out:
#    Date received          Product                             Sub-product  \
# 4     09/13/2014  Debt collection                             Credit card
# 5     11/13/2013         Mortgage  Conventional adjustable mortgage (ARM)
# 17    11-07-2014         Mortgage             Conventional fixed mortgage
#
#                                        Issue                   Sub-issue  \
# 4                      Communication tactics  Frequent or repeated calls
# 5   Loan servicing, payments, escrow account                         NaN
# 17  Loan modification,collection,foreclosure                         NaN
#
#    Consumer Complaint Company Public Response         Company State ZIP code  \
# 4                 NaN                     NaN  CITIBANK, N.A.    VA    23233
# 5                 NaN                     NaN    U.S. BANCORP    MN    48322
# 17                NaN                     NaN    U.S. BANCORP    MT    59801
#
# ...

# %%
#df['Product'].value_counts()
df1= df.groupby(['Issue'])['Sub-issue'].count().to_frame().reset_index()
df1
# Out:
#                                                  Issue  Sub-issue
# 0                                 APR or interest rate          0
# 1              Account opening, closing, or management          0
# 2                            Account terms and changes          0
# 3                                         Adding money          0
# 4                                          Advertising          5
# 5                            Advertising and marketing          0
# 6    Advertising and marketing, including promotion...        447
# 7                Advertising, marketing or disclosures          0
# 8                         Application processing delay          0
# 9             Application, originator, mortgage broker          0
# 10              Applied for loan/did not receive money          0
# 11                             Applying for a mortgage          0
# 12   Applying for a mortgage or refinancing an exis...          0
# ...

# %%
import plotly.express as px
# This dataframe has 244 lines, but 4 distinct values for `day`
df = px.data.tips()
fig = px.pie(df, values='tip', names='day')
fig.show()

# %%
list(df['Company'].unique())
# Out:
# ['M&T BANK CORPORATION',
#  'TRANSUNION INTERMEDIATE HOLDINGS, INC.',
#  'CITIZENS FINANCIAL GROUP, INC.',
#  'AMERICAN EXPRESS COMPANY',
#  'CITIBANK, N.A.',
#  'U.S. BANCORP',
#  'California Accounts Service',
#  'Experian Information Solutions Inc.',
#  'Aldridge Pite, LLP',
#  'OCWEN LOAN SERVICING LLC',
#  'Shellpoint Partners, LLC',
#  'Student Loan Finance Corporation',
#  'The CBE Group, Inc.',
#  'FIRST NATIONAL BANK OF OMAHA',
#  'EQUIFAX, INC.',
#  'SQUARETWO FINANCIAL CORPORATION',
#  'WELLS FARGO & COMPANY',
#  'PHH Mortgage Services Corporation',
#  'UNITED SERVICES AUTOMOBILE ASSOCIATION',
#  'Ditech Financial LLC',
#  'NATIONSTAR MORTGAGE',
#  'Navient Solutions, LLC.',
#  'AMERICAN NEIGHBORHOOD MORTGAGE',
#  'HSBC NORTH AMERICA HOLDINGS INC.',
#  'Revenue Recovery Corporation',
#  'FREEDOM MORTGAGE COMPANY',
#  'ALLY FINANCIAL INC.',
#  'MUFG UNION BANK, NATIONAL ASSOCIATION',
#  'BARCLAYS BANK DELAWARE',
#  'JPMORGAN CHASE & CO.',
# ...

# %%
df1= df.groupby(['Company'])['Consumer disputed?'].count().to_frame().reset_index()
df1
# Out:
#                                  Company  Consumer disputed?
# 0  BANK OF AMERICA, NATIONAL ASSOCIATION               65992
# 1                         CITIBANK, N.A.               34768
# 2                 GOLDMAN SACHS BANK USA                 100
# 3                          PNC Bank N.A.                8666
# 4                           U.S. BANCORP               12347
# 5                  WELLS FARGO & COMPANY               53694

# %%
import plotly.express as px
df = px.data.gapminder().query("year == 2007").query("continent == 'Europe'")
df.loc[df['pop'] < 2.e6, 'country'] = 'Other countries' # Represent only large countries
fig = px.pie(df, values='pop', names='country', title='Population of European continent')
fig.show()

# %%
pd.crosstab(df['Company'],df['Consumer disputed?']).plot(kind='bar',rot=(0), figsize=(20, 8))
plt.xticks()
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'BANK OF AMERICA, NATIONAL ASSOCIATION'),
#   Text(1, 0, 'CITIBANK, N.A.'),
#   Text(2, 0, 'GOLDMAN SACHS BANK USA'),
#   Text(3, 0, 'PNC Bank N.A.'),
#   Text(4, 0, 'U.S. BANCORP'),
#   Text(5, 0, 'WELLS FARGO & COMPANY')])

# %%
pd.crosstab(df['Company'],df['Timely response?']).plot(kind='bar',rot=(0), color= ["Red", "Green"],   figsize=(20, 8))
plt.xticks()
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'BANK OF AMERICA, NATIONAL ASSOCIATION'),
#   Text(1, 0, 'CITIBANK, N.A.'),
#   Text(2, 0, 'GOLDMAN SACHS BANK USA'),
#   Text(3, 0, 'PNC Bank N.A.'),
#   Text(4, 0, 'U.S. BANCORP'),
#   Text(5, 0, 'WELLS FARGO & COMPANY')])

# %%
plot = df.plot.pie(subplots=True, figsize=(11, 6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [81], in <cell line: 1>()
# ----> 1 df = pd.DataFrame({'Company': Company,
#       2                    'Consumer disputed?': Company}, index=index)
#       3 ax = df.plot.bar(rot=0)
#
# NameError: name 'Company' is not defined

# %%
fig = plt.figure(figsize =(10, 7))
plt.pie(, labels = df1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [65], in <cell line: 2>()
#       1 fig = plt.figure(figsize =(10, 7))
# ----> 2 plt.pie(Issue, labels = df1)
#       3 plt.show()
#
# NameError: name 'Issue' is not defined

# %%
df['Company'].value_counts()
# Out:
# EQUIFAX, INC.                                          83659
# BANK OF AMERICA, NATIONAL ASSOCIATION                  74423
# Experian Information Solutions Inc.                    72858
# TRANSUNION INTERMEDIATE HOLDINGS, INC.                 66269
# WELLS FARGO & COMPANY                                  62345
#                                                        ...
# JLM R.E. INVESTMENTS                                       1
# A.L. Babbs and Associates, LLC                             1
# Aspen Home Mortgage Group                                  1
# Retailers' Credit Association of Grass Valley, Inc.        1
# Pipeline Ventures                                          1
# Name: Company, Length: 4780, dtype: int64

# %%
df= df[df['Company'].isin(['BANK OF AMERICA, NATIONAL ASSOCIATION', 'CITIBANK, N.A.', 'WELLS FARGO & COMPANY' , 'U.S. BANCORP','PNC Bank N.A.', 'GOLDMAN SACHS BANK USA'])]

# %%
df['Company'].value_counts()
# Out:
# BANK OF AMERICA, NATIONAL ASSOCIATION    74423
# WELLS FARGO & COMPANY                    62345
# CITIBANK, N.A.                           41763
# U.S. BANCORP                             14778
# PNC Bank N.A.                            10125
# GOLDMAN SACHS BANK USA                     182
# Name: Company, dtype: int64

# %%
fig,fig = plt.subplots(figsize=(18,6))
sns.countplot(x='Company',data=df)
# Out:
# <AxesSubplot:xlabel='Company', ylabel='count'>

# %%
df.columns
# Out:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer Complaint', 'Company Public Response', 'Company', 'State',
#        'ZIP code', 'Tags', 'Consumer consent provided?', 'Submitted via',
#        'Date Sent to Company', 'Company Response to Consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID',
#        'Unnamed: 18'],
#       dtype='object')

# %%
df.Company
# Out:
# 4                                 CITIBANK, N.A.
# 5                                   U.S. BANCORP
# 17                                  U.S. BANCORP
# 18                         WELLS FARGO & COMPANY
# 30                         WELLS FARGO & COMPANY
#                            ...
# 1024989    BANK OF AMERICA, NATIONAL ASSOCIATION
# 1024993    BANK OF AMERICA, NATIONAL ASSOCIATION
# 1024994    BANK OF AMERICA, NATIONAL ASSOCIATION
# 1024995    BANK OF AMERICA, NATIONAL ASSOCIATION
# 1025003    BANK OF AMERICA, NATIONAL ASSOCIATION
# Name: Company, Length: 203616, dtype: object

# %%
df1 =df.groupby(['Company', 'Product'])
df1

# %%
pd.crosstab(df['Company'],df['Product']).plot(kind='bar', figsize=(20, 8))
plt.xticks()
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'BANK OF AMERICA, NATIONAL ASSOCIATION'),
#   Text(1, 0, 'CITIBANK, N.A.'),
#   Text(2, 0, 'GOLDMAN SACHS BANK USA'),
#   Text(3, 0, 'PNC Bank N.A.'),
#   Text(4, 0, 'U.S. BANCORP'),
#   Text(5, 0, 'WELLS FARGO & COMPANY')])

# %%
dff=pd.DataFrame(df1)
dff.head()
# Out:
#                                                    0  \
# 0  (BANK OF AMERICA, NATIONAL ASSOCIATION, Bank a...
# 1  (BANK OF AMERICA, NATIONAL ASSOCIATION, Checki...
# 2  (BANK OF AMERICA, NATIONAL ASSOCIATION, Consum...
# 3  (BANK OF AMERICA, NATIONAL ASSOCIATION, Credit...
# 4  (BANK OF AMERICA, NATIONAL ASSOCIATION, Credit...
#
#                                                    1
# 0          Date received                  Product...
# 1          Date received                      Pro...
# 2         Date received        Product           ...
# 3          Date received      Product Sub-product...
# 4          Date received                      Pro...

# %%
#import plotly.graph_objects as go
#fig = go.Figure(go.Bar(x= dff['Company'],y= dff['Product'],orientation='v'))
#fig.show()

# %%
#sns.countplot(df.Company)
plt.hist(df['Company'])
# Out:
# (array([924208.,  49479.,  22041.,  11112.,   6505.,   4437.,   2777.,
#           1469.,   1445.,   1537.]),
#  array([   0. ,  477.9,  955.8, 1433.7, 1911.6, 2389.5, 2867.4, 3345.3,
#         3823.2, 4301.1, 4779. ]),
#  <BarContainer object of 10 artists>)

# %%
df.groupby(['Company','Consumer Complaint']).count()
# Out:
#                                                                                              Date received  \
# Company                                  Consumer Complaint
# (Former)Shapiro, Swertfeger & Hasty, LLP Delinquent credit Obligations - I am repeatdly ...              1
#                                          I am in deep student loan debt, started a repay...              1
#                                          Incorrect information is popping up on my crimi...              1
#                                          My complaint is with  XXXX   XXXX  apartments. ...              1
#                                          Upon being denied credit from a lender for " to...              1
# ...                                                                                                    ...
# reekside Recovery And Capital Management They called my wife and gave her a phone number...              1
# ...

# %%
df1 =df.groupby(['Company','Consumer Complaint']).count().to_frame().rename(columns={'id':'count'}).reset_index()
df1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 df1 =df.groupby(['Company','Consumer Complaint']).count().to_frame().rename(columns={'id':'count'}).reset_index()
#       2 df1
#
# File ~\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'
